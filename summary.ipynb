# %%
import pygame
def play_music(name):
    pygame.mixer.init()
    pygame.mixer.music.load(name)
    pygame.mixer.music.play()
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from transformers import BartForConditionalGeneration, BartTokenizer
from pypdf import PdfReader
import google.generativeai as genai
import PIL.Image
import os
genai.configure(api_key='key')


model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")


import time
def summaryies(text):
    prompt = "Summarize the following paragraph in 500 words and return only the summary, without any explanation: \"" + text + "\""
    model = genai.GenerativeModel(model_name="gemini-1.5-flash")
    response = model.generate_content(prompt)
    time.sleep(13)  
    return response.text

def level1(path):
    reader = PdfReader(path)
    summary=""
    for i in reader.pages:
        inputs = tokenizer([i.extract_text().replace("\n","")], max_length=1024, return_tensors="pt", truncation=True).to(device)
        summary_ids = model.generate(inputs["input_ids"], num_beams=32, max_length=200, early_stopping=False)
        summary =summary +"\n"+ tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %%
p1_l1=level1("Empirical_Evaluation_of_Gated_Recurrent_Neural_Network_Architectures_in_Aviation_Delay_Prediction.pdf")
play_music('One of the Girls (instrumental).mp3')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 p1_l1=level1("Empirical_Evaluation_of_Gated_Recurrent_Neural_Network_Architectures_in_Aviation_Delay_Prediction.pdf")
#       2 play_music('One of the Girls (instrumental).mp3')
#
# Cell In[5], line 26, in level1(path)
#      24 for i in reader.pages:
#      25     inputs = tokenizer([i.extract_text().replace("\n","")], max_length=1024, return_tensors="pt", truncation=True)
# ---> 26     summary_ids = model.generate(inputs["input_ids"], num_beams=32, max_length=200, early_stopping=False)
#      27     summary =summary +"\n"+ tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#      28 return summary
#
# File c:\Users\Gaurav B V\anaconda3\envs\myenv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
# ...

# %%
p2_l1=level1("Iterative_machine_and_deep_learning_approach_for_aviation_delay_prediction.pdf")
play_music('One of the Girls (instrumental).mp3')

# %%
p1_l2=summaryies(p1_l1)
p2_l2=summaryies(p2_l1)
play_music('One of the Girls (instrumental).mp3')

# %%
import pandas as pd
df= pd.read_json("",)
